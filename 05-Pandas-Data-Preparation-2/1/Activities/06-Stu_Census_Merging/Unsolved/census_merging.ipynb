# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %%
# Store filepaths into variable
state_avg_df = Path('Resources/state_avg.csv')
state_totals_df = Path('Resources/state_totals.csv')

# %%
# Read in files.
state_avg_df = pd.read_csv (state_avg_df)
state_totals_df = pd.read_csv(state_totals_df)

# %%
# Display the state averages.
state_avg_df
# Out:
#      Year          State  Average Median Age by County  \
# 0    2016        Alabama                     40.250746
# 1    2016         Alaska                     36.624138
# 2    2016        Arizona                     39.613333
# 3    2016       Arkansas                     41.140000
# 4    2016     California                     39.281034
# ..    ...            ...                           ...
# 203  2019       Virginia                     42.136090
# 204  2019     Washington                     42.146154
# 205  2019  West Virginia                     44.365455
# 206  2019      Wisconsin                     43.656944
# 207  2019        Wyoming                     40.443478
#
#      Average Household Income by County  Average Per Capita Income by County
# 0                          38834.925373                         21232.746269
# 1                          64801.655172                         31052.103448
# ...

# %%
# Display the state totals
state_totals_df
# Out:
#      Year          State  Total Population  Total Employed Civilians  \
# 0    2016        Alabama           4841164                 2042025.0
# 1    2016         Alaska            736855                  353954.0
# 2    2016        Arizona           6728577                 2879372.0
# 3    2016       Arkansas           2968472                 1266552.0
# 4    2016     California          38654206                17577142.0
# ..    ...            ...               ...                       ...
# 203  2019       Virginia           8454463                 4156018.0
# 204  2019     Washington           7404107                 3594279.0
# 205  2019  West Virginia           1817305                  740910.0
# 206  2019      Wisconsin           5790716                 2982359.0
# 207  2019        Wyoming            581024                  288503.0
#
#      Total Unemployed Civilians  Total People in the Military  \
# 0                      184479.0                       12150.0
# ...

# %%
# Merge the two DataFrames together based on the Year and State they share
merge_df= pd.merge(state_totals_df, state_avg_df, on=["Year", "State"])
merge_df.head()
# Out:
#    Year       State  Total Population  Total Employed Civilians  \
# 0  2016     Alabama           4841164                 2042025.0
# 1  2016      Alaska            736855                  353954.0
# 2  2016     Arizona           6728577                 2879372.0
# 3  2016    Arkansas           2968472                 1266552.0
# 4  2016  California          38654206                17577142.0
#
#    Total Unemployed Civilians  Total People in the Military  \
# 0                    184479.0                       12150.0
# 1                     30139.0                       16382.0
# 2                    249972.0                       17373.0
# 3                     93190.0                        4445.0
# 4                   1683726.0                      130452.0
#
#    Total Population in Poverty  Average Median Age by County  \
# 0                     868666.0                     40.250746
# 1                      72826.0                     36.624138
# ...

# %%
# Create a DataFrame that filters the data on only 2019
slice_filtered_df = merge_df[merge_df["Year"] == 2019]
slice_filtered_df.head()
slice_filtered_df.copy()
# Out:
#      Year                 State  Total Population  Total Employed Civilians  \
# 156  2019               Alabama           4876250                 2097384.0
# 157  2019                Alaska            737068                  347774.0
# 158  2019               Arizona           7050299                 3130658.0
# 159  2019              Arkansas           2999370                 1303490.0
# 160  2019            California          39283497                18591241.0
# 161  2019              Colorado           5610349                 2904589.0
# 162  2019           Connecticut           3575074                 1815636.0
# 163  2019              Delaware            957248                  455620.0
# 164  2019  District of Columbia            692683                  376871.0
# 165  2019               Florida          20901636                 9495353.0
# 166  2019               Georgia          10403847                 4834622.0
# ...

# %%
# Add a new column that calculates the Poverty Rate
slice_filtered_df["Poverty Rate (%)"] = filtered_df["Total Population in Poverty"]/\
                                    filtered_df["Total Population"] *100
slice_filtered_df.head()
# Out:
# /var/folders/0v/k5cxfnrj4_x27cyj9ynqp8qh0000gn/T/ipykernel_3636/3804361804.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slice_filtered_df["Poverty Rate (%)"] = filtered_df["Total Population in Poverty"]/\
#      Year       State  Total Population  Total Employed Civilians  \
# 156  2019     Alabama           4876250                 2097384.0
# 157  2019      Alaska            737068                  347774.0
# 158  2019     Arizona           7050299                 3130658.0
# 159  2019    Arkansas           2999370                 1303490.0
# 160  2019  California          39283497                18591241.0
#
#      Total Unemployed Civilians  Total People in the Military  \
# ...

# %%
# Sort the data by Poverty Rate and Average Per Capita Income by County, Highest to Lowest


# Reset Index
# Out:
#    Year          State  Average Median Age by County  \
# 0  2019    Puerto Rico                     41.656410
# 1  2019    Mississippi                     38.748780
# 2  2019     New Mexico                     41.739394
# 3  2019      Louisiana                     38.053125
# 4  2019  West Virginia                     44.365455
#
#    Average Household Income by County  Average Per Capita Income by County  \
# 0                        19300.025641                         11067.884615
# 1                        39613.073171                         21758.451220
# 2                        43722.969697                         24620.212121
# 3                        44874.015625                         24386.296875
# 4                        44892.236364                         24691.836364
#
#    Total Population  Total Employed Civilians  Total Unemployed Civilians  \
# 0           3318447                 1028513.0                    196934.0
# ...

# %%
# Print out the data for the state or territory with the highest poverty rate
# Out:
# Year                                           2019
# State                                   Puerto Rico
# Average Median Age by County               41.65641
# Average Household Income by County     19300.025641
# Average Per Capita Income by County    11067.884615
# Total Population                            3318447
# Total Employed Civilians                  1028513.0
# Total Unemployed Civilians                 196934.0
# Total People in the Military                 1845.0
# Total Population in Poverty               1449091.0
# Poverty Rate (%)                          43.667746
# Name: 0, dtype: object

# %%
# Print out the data for the state or territory with the lowest poverty rate with one line of code
# Out:
# Year                                            2019
# State                                  New Hampshire
# Average Median Age by County                   44.54
# Average Household Income by County           69308.2
# Average Per Capita Income by County          36819.6
# Total Population                             1348124
# Total Employed Civilians                    729701.0
# Total Unemployed Civilians                   27430.0
# Total People in the Military                  1950.0
# Total Population in Poverty                  98682.0
# Poverty Rate (%)                             7.31995
# Name: 51, dtype: object
